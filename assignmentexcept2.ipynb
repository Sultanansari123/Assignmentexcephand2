# %%
"""Ans1-To catch and provide to specific treatment to a subset of existing python exception.There are the exception related to business logic
and workflow .It is useful for the application users or to developers to understand the exact problem."""
# Out:
# 'Ans1-To catch and provide to specific treatment to a subset of existing python exception.There are the exception related to business logic\nand workflow .It is useful for the application users or to developers to understand the exact problem.'

# %%
import inspect as ipt

# %%
def tree_class(cls,ind=0):
    #then we will print the name of the class
    print('-'*ind,cls.__name__)
    #now we will iterate the subclass
    for k in cls.__subclasses__():
        tree_class(k,ind+3)
print("the heirarchy of inbuilt exception is:")
ipt.getclasstree(ipt.getmro(BaseException))#ipt .getmro will return the tuple
#function call
tree_class(BaseException)
# Out:
# the heirarchy of inbuilt exception is:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
#Ans3-
arithematic=5/0
print(arithematic)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Ans3-
# ----> 2 arithematic=5/0
#       3 print(arithematic)
#
# ZeroDivisionError: division by zero

# %%
try:
    arithmatic=5/0
    print(arithmatic)
except ArithmeticError:
    print("you have just made an arithematic error")
# Out:
# you have just made an arithematic error

# %%
#Ans4-the loookup error exception in python form the base class for all exceptions that are raisedwhen an index
age={'Jim':30,'Pam':40,'Kevin':50}
age['Michael']#produce key error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 #Ans4-the loookup error exception in python form the base class for all exceptions that are raisedwhen an index
#       2 age={'Jim':30,'Pam':40,'Kevin':50}
# ----> 3 age['Michael']
#
# KeyError: 'Michael'

# %%
try:
    l=[1,2,3,4,5]
    print(l[5])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
#Ans5-
#you do not have the module you tried importing installed on your computer.
#you spelled a module incorrectly.
#you use an incorrect casing
 try:
        def hello():
    print("hello")

# %%
import demo.test as test1
    test1.hello()
except ModuleNotFoundError:
    print("module not found")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import demo.test as test1
#       2 try:
#       3         def hello():
#
# ModuleNotFoundError: No module named 'demo'

# %%
"""Ans6-list down some best practices for exception handling in python
1-prevent program from crashing if an error occurs
2-save time debugging error
3-helps define requirements for the programs
